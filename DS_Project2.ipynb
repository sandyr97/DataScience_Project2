# %% [markdown]
# # To Be, Or Not To Be

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Load dataframe

# %%
df=pd.read_csv("Shakespeare_data.csv")
df.head(10)
# Out:
#    Dataline      Play  PlayerLinenumber ActSceneLine         Player  \
# 0         1  Henry IV               NaN          NaN            NaN
# 1         2  Henry IV               NaN          NaN            NaN
# 2         3  Henry IV               NaN          NaN            NaN
# 3         4  Henry IV               1.0        1.1.1  KING HENRY IV
# 4         5  Henry IV               1.0        1.1.2  KING HENRY IV
# 5         6  Henry IV               1.0        1.1.3  KING HENRY IV
# 6         7  Henry IV               1.0        1.1.4  KING HENRY IV
# 7         8  Henry IV               1.0        1.1.5  KING HENRY IV
# 8         9  Henry IV               1.0        1.1.6  KING HENRY IV
# 9        10  Henry IV               1.0        1.1.7  KING HENRY IV
#
#                                           PlayerLine
# 0                                              ACT I
# 1                       SCENE I. London. The palace.
# 2  Enter KING HENRY, LORD JOHN OF LANCASTER, the ...
# 3             So shaken as we are, so wan with care,
# 4         Find we a time for frighted peace to pant,
# 5     And breathe short-winded accents of new broils
# 6            To be commenced in strands afar remote.
# 7          No more the thirsty entrance of this soil
# 8  Shall daub her lips with her own children's bl...
# 9   Nor more shall trenching war channel her fields,

# %% [markdown]
# ## Clean the data:

# %%
df['PlayerLinenumber'] = df['PlayerLinenumber'].replace(np.nan, 0)
df['ActSceneLine'] = df['ActSceneLine'].replace(np.nan, "0.0.0")
df['Player'] = df['Player'].replace(np.nan, "NO ONE")
df.head(10)
# Out:
#    Dataline      Play  PlayerLinenumber ActSceneLine         Player  \
# 0         1  Henry IV               0.0        0.0.0         NO ONE
# 1         2  Henry IV               0.0        0.0.0         NO ONE
# 2         3  Henry IV               0.0        0.0.0         NO ONE
# 3         4  Henry IV               1.0        1.1.1  KING HENRY IV
# 4         5  Henry IV               1.0        1.1.2  KING HENRY IV
# 5         6  Henry IV               1.0        1.1.3  KING HENRY IV
# 6         7  Henry IV               1.0        1.1.4  KING HENRY IV
# 7         8  Henry IV               1.0        1.1.5  KING HENRY IV
# 8         9  Henry IV               1.0        1.1.6  KING HENRY IV
# 9        10  Henry IV               1.0        1.1.7  KING HENRY IV
#
#                                           PlayerLine
# 0                                              ACT I
# 1                       SCENE I. London. The palace.
# 2  Enter KING HENRY, LORD JOHN OF LANCASTER, the ...
# 3             So shaken as we are, so wan with care,
# 4         Find we a time for frighted peace to pant,
# 5     And breathe short-winded accents of new broils
# 6            To be commenced in strands afar remote.
# 7          No more the thirsty entrance of this soil
# 8  Shall daub her lips with her own children's bl...
# 9   Nor more shall trenching war channel her fields,

# %%
df.shape
df.describe()
# Out:
#             Dataline  PlayerLinenumber
# count  111396.000000     111396.000000
# mean    55698.500000         36.884341
# std     32157.399631         39.985760
# min         1.000000          0.000000
# 25%     27849.750000         10.000000
# 50%     55698.500000         25.000000
# 75%     83547.250000         50.000000
# max    111396.000000        405.000000

# %%
temp = df["ActSceneLine"].str.split(".", n = 2, expand = True)
temp.head(10)
# Out:
#    0  1  2
# 0  0  0  0
# 1  0  0  0
# 2  0  0  0
# 3  1  1  1
# 4  1  1  2
# 5  1  1  3
# 6  1  1  4
# 7  1  1  5
# 8  1  1  6
# 9  1  1  7

# %%
df["Act"]= temp[0] 
df["Scene"]= temp[1] 
df["Line"]= temp[1] 

# Dropping old column
df.drop(columns =["ActSceneLine"], inplace = True) 
df.head(10)
# Out:
#    Dataline      Play  PlayerLinenumber         Player  \
# 0         1  Henry IV               0.0         NO ONE
# 1         2  Henry IV               0.0         NO ONE
# 2         3  Henry IV               0.0         NO ONE
# 3         4  Henry IV               1.0  KING HENRY IV
# 4         5  Henry IV               1.0  KING HENRY IV
# 5         6  Henry IV               1.0  KING HENRY IV
# 6         7  Henry IV               1.0  KING HENRY IV
# 7         8  Henry IV               1.0  KING HENRY IV
# 8         9  Henry IV               1.0  KING HENRY IV
# 9        10  Henry IV               1.0  KING HENRY IV
#
#                                           PlayerLine Act Scene Line
# 0                                              ACT I   0     0    0
# 1                       SCENE I. London. The palace.   0     0    0
# 2  Enter KING HENRY, LORD JOHN OF LANCASTER, the ...   0     0    0
# 3             So shaken as we are, so wan with care,   1     1    1
# 4         Find we a time for frighted peace to pant,   1     1    1
# 5     And breathe short-winded accents of new broils   1     1    1
# 6            To be commenced in strands afar remote.   1     1    1
# 7          No more the thirsty entrance of this soil   1     1    1
# 8  Shall daub her lips with her own children's bl...   1     1    1
# 9   Nor more shall trenching war channel her fields,   1     1    1

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
df['PlayLE'] = le.fit_transform(df["Play"].astype(str))
df['PlayerLE'] = le.fit_transform(df["Player"].astype(str))
df['LineTextLE'] = le.fit_transform(df["PlayerLine"].astype(str))
df['ActLE'] = le.fit_transform(df["Act"].astype(str))
df['SceneLE'] = le.fit_transform(df["Scene"].astype(str))
df['LineLE'] = le.fit_transform(df["Line"].astype(str))
df['LineNumberLE'] = df['PlayerLinenumber'].astype(int)
df.head(30)
# Out:
#     Dataline      Play  PlayerLinenumber         Player  \
# 0          1  Henry IV               0.0         NO ONE
# 1          2  Henry IV               0.0         NO ONE
# 2          3  Henry IV               0.0         NO ONE
# 3          4  Henry IV               1.0  KING HENRY IV
# 4          5  Henry IV               1.0  KING HENRY IV
# 5          6  Henry IV               1.0  KING HENRY IV
# 6          7  Henry IV               1.0  KING HENRY IV
# 7          8  Henry IV               1.0  KING HENRY IV
# 8          9  Henry IV               1.0  KING HENRY IV
# 9         10  Henry IV               1.0  KING HENRY IV
# 10        11  Henry IV               1.0  KING HENRY IV
# 11        12  Henry IV               1.0  KING HENRY IV
# 12        13  Henry IV               1.0  KING HENRY IV
# 13        14  Henry IV               1.0  KING HENRY IV
# 14        15  Henry IV               1.0  KING HENRY IV
# 15        16  Henry IV               1.0  KING HENRY IV
# 16        17  Henry IV               1.0  KING HENRY IV
# 17        18  Henry IV               1.0  KING HENRY IV
# 18        19  Henry IV               1.0  KING HENRY IV
# 19        20  Henry IV               1.0  KING HENRY IV
# 20        21  Henry IV               1.0  KING HENRY IV
# 21        22  Henry IV               1.0  KING HENRY IV
# 22        23  Henry IV               1.0  KING HENRY IV
# 23        24  Henry IV               1.0  KING HENRY IV
# 24        25  Henry IV               1.0  KING HENRY IV
# 25        26  Henry IV               1.0  KING HENRY IV
# 26        27  Henry IV               1.0  KING HENRY IV
# 27        28  Henry IV               1.0  KING HENRY IV
# 28        29  Henry IV               1.0  KING HENRY IV
# 29        30  Henry IV               1.0  KING HENRY IV
#
#                                            PlayerLine Act Scene Line  PlayLE  \
# 0                                               ACT I   0     0    0       9
# 1                        SCENE I. London. The palace.   0     0    0       9
# 2   Enter KING HENRY, LORD JOHN OF LANCASTER, the ...   0     0    0       9
# 3              So shaken as we are, so wan with care,   1     1    1       9
# 4          Find we a time for frighted peace to pant,   1     1    1       9
# 5      And breathe short-winded accents of new broils   1     1    1       9
# 6             To be commenced in strands afar remote.   1     1    1       9
# 7           No more the thirsty entrance of this soil   1     1    1       9
# 8   Shall daub her lips with her own children's bl...   1     1    1       9
# 9    Nor more shall trenching war channel her fields,   1     1    1       9
# 10      Nor bruise her flowerets with the armed hoofs   1     1    1       9
# 11              Of hostile paces: those opposed eyes,   1     1    1       9
# 12      Which, like the meteors of a troubled heaven,   1     1    1       9
# 13          All of one nature, of one substance bred,   1     1    1       9
# 14             Did lately meet in the intestine shock   1     1    1       9
# 15                And furious close of civil butchery   1     1    1       9
# 16         Shall now, in mutual well-beseeming ranks,   1     1    1       9
# 17           March all one way and be no more opposed   1     1    1       9
# 18          Against acquaintance, kindred and allies:   1     1    1       9
# 19       The edge of war, like an ill-sheathed knife,   1     1    1       9
# 20  No more shall cut his master. Therefore, friends,   1     1    1       9
# 21              As far as to the sepulchre of Christ,   1     1    1       9
# 22       Whose soldier now, under whose blessed cross   1     1    1       9
# 23             We are impressed and engaged to fight,   1     1    1       9
# 24        Forthwith a power of English shall we levy,   1     1    1       9
# 25     Whose arms were moulded in their mothers' womb   1     1    1       9
# 26         To chase these pagans in those holy fields   1     1    1       9
# 27         Over whose acres walk'd those blessed feet   1     1    1       9
# 28       Which fourteen hundred years ago were nail'd   1     1    1       9
# 29             For our advantage on the bitter cross.   1     1    1       9
#
#     PlayerLE  LineTextLE  ActLE  SceneLE  LineLE  LineNumberLE
# 0        595        2574      0        0       0             0
# 1        595       60108      0        0       0             0
# 2        595       23218      0        0       0             0
# 3        457       63734      1        1       1             1
# 4        457       25781      1        1       1             1
# 5        457        5120      1        1       1             1
# 6        457       77594      1        1       1             1
# 7        457       51386      1        1       1             1
# 8        457       61525      1        1       1             1
# 9        457       52258      1        1       1             1
# 10       457       52142      1        1       1             1
# 11       457       55407      1        1       1             1
# 12       457       87603      1        1       1             1
# 13       457        3633      1        1       1             1
# 14       457       21134      1        1       1             1
# 15       457        5938      1        1       1             1
# 16       457       61627      1        1       1             1
# 17       457       47443      1        1       1             1
# 18       457        2959      1        1       1             1
# 19       457       69975      1        1       1             1
# 20       457       51372      1        1       1             1
# 21       457       12015      1        1       1             1
# 22       457       88688      1        1       1             1
# 23       457       82253      1        1       1             1
# 24       457       27740      1        1       1             1
# 25       457       88527      1        1       1             1
# 26       457       77853      1        1       1             1
# 27       457       57624      1        1       1             1
# 28       457       87004      1        1       1             1
# 29       457       26908      1        1       1             1

# %%
# Labels are the values we want to predict
labels = np.array(df['PlayerLE'])

feature_list = np.array(df[['ActLE','SceneLE','PlayLE']])

# %%
# Splitting the data between 80% train and 20% test
from sklearn.model_selection import train_test_split

train_features, test_features, train_labels, test_labels = train_test_split(feature_list, labels, test_size=0.25, random_state=42)

# %%
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
# Out:
# Training Features Shape: (83547, 3)
# Training Labels Shape: (83547,)
# Testing Features Shape: (27849, 3)
# Testing Labels Shape: (27849,)

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf.fit(train_features, train_labels)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=1000,
#                       n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                       warm_start=False)

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()
model.fit(train_features,train_labels)
prediction_labels = model.predict(test_features)
print("Accuracy: ", metrics.accuracy_score(test_labels,prediction_labels))
# Out:
# Accuracy:  0.4195123702825954

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn import tree

# Create a Gaussian Classifier
forest = RandomForestClassifier(n_estimators=100) 
# Train the model using the trianing sets
forest.fit(train_features,train_labels)
prediction_labels = forest.predict(test_features)
# Check the accuracy using actual and predicted values
print("Accuracy: ", metrics.accuracy_score(test_labels,prediction_labels))
# Out:
# Accuracy:  0.4196560020108442

# %% [markdown]
# # References
# https://towardsdatascience.com/random-forest-in-python-24d0893d51c0
